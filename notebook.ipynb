# %%
from model.TrafficModel import TrafficModel
import agentpy as ap
import matplotlib.pyplot as plt
import numpy as np
import IPython
print("**Multiagent Traffic System Simulator**")
print("Team No.6")

# Parameters
parameters = {
    "size" : 20,
    "cars" : 10,
    "lights" : 2,
    "max_inertia" : 2,
    "max_humans": 12,
    "safe_distance": 1.5,
}

tModel = TrafficModel(parameters)
tModel.setup()
def my_plot(m, ax):
    ax.set_title("Traffic Model")
    ax.set_xlim([0, parameters["size"]])
    ax.set_ylim([0, parameters["size"]])
    ax.set_xticks(np.arange(0,parameters["size"], 1))
    ax.set_yticks(np.arange(0,parameters["size"], 1))
    ax.grid(True)
    pos = m.space.positions.values()
    for entry in pos:
        print(entry)
    pos = np.array(list(pos)).T
    ax.scatter(*pos, s=5, c='black')
    ax.set_aspect('equal')
    ax.set_xlabel("X")
    ax.set_ylabel("Y")

def animation():
    fig, ax = plt.subplots()
    anim = ap.animate(tModel,fig, ax, my_plot)
    return IPython.display.HTML(anim.to_jshtml(fps=30))
animation()
# Out:
# **Multiagent Traffic System Simulator**
# Team No.6
# Car: mass: 2 type: MODEL_TYPE.CAR direction: 1
# ----
# Car: mass: 1 type: MODEL_TYPE.BUS direction: 0
# ----
# Car: mass: 2 type: MODEL_TYPE.BUS direction: 1
# ----
# Car: mass: 1 type: MODEL_TYPE.BUS direction: 1
# ----
# Car: mass: 2 type: MODEL_TYPE.CAR direction: 0
# ----
# Car: mass: 2 type: MODEL_TYPE.CAR direction: 1
# ----
# Car: mass: 1 type: MODEL_TYPE.TRUCK direction: 1
# ----
# Car: mass: 2 type: MODEL_TYPE.CAR direction: 0
# ----
# Car: mass: 2 type: MODEL_TYPE.TRUCK direction: 0
# ----
# Car: mass: 1 type: MODEL_TYPE.BUS direction: 0
# ----
# Human is setup
# Human is setup
# Human is setup
# Human is setup
# Human is setup
# Human is setup
# Human is setup
# Human is setup
# Human is setup
# Car: mass: 2 type: MODEL_TYPE.TRUCK direction: 0
# ----
# Car: mass: 1 type: MODEL_TYPE.TRUCK direction: 0
# ----
# Car: mass: 1 type: MODEL_TYPE.TRUCK direction: 0
# ----
# Car: mass: 2 type: MODEL_TYPE.TRUCK direction: 0
# ----
# Car: mass: 2 type: MODEL_TYPE.TRUCK direction: 0
# ----
# Car: mass: 1 type: MODEL_TYPE.TRUCK direction: 1
# ----
# Car: mass: 2 type: MODEL_TYPE.BUS direction: 1
# ----
# Car: mass: 2 type: MODEL_TYPE.CAR direction: 0
# ----
# Car: mass: 2 type: MODEL_TYPE.BUS direction: 0
# ----
# Car: mass: 2 type: MODEL_TYPE.CAR direction: 1
# ----
# Human is setup
# [9. 1.]
# [9. 0.]
# [9. 7.]
# [9. 1.]
# [10.  4.]
# [ 6. 10.]
# [5. 9.]
# [9. 2.]
# [ 2. 10.]
# [ 7. 10.]
# [7 7]
# [ 7 13]
# [9. 1.]
# [9. 0.]
# [9. 7.]
# [9. 1.]
# [10.  4.]
# [ 6. 10.]
# [5. 9.]
# [9. 2.]
# [ 2. 10.]
# [ 7. 10.]
# [7 7]
# [ 7 13]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-c19124dcfa1d> in <module>
#      39     anim = ap.animate(tModel,fig, ax, my_plot)
#      40     return IPython.display.HTML(anim.to_jshtml(fps=30))
# ---> 41 animation()
#
# <ipython-input-1-c19124dcfa1d> in animation()
#      38     fig, ax = plt.subplots()
#      39     anim = ap.animate(tModel,fig, ax, my_plot)
# ---> 40     return IPython.display.HTML(anim.to_jshtml(fps=30))
#      41 animation()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\animation.py in to_jshtml(self, fps, embed_frames, default_mode)
#    1400                                     embed_frames=embed_frames,
#    1401                                     default_mode=default_mode)
# -> 1402                 self.save(str(path), writer=writer)
#    1403                 self._html_representation = path.read_text()
#    1404
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1168             else:
#    1169                 total_frames = sum(save_count_list)
# -> 1170             for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1171                 for anim, d in zip(all_anim, data):
#    1172                     # TODO: See if turning off blit is really necessary
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\agentpy\visualization.py in frames()
#      68                     pre_steps += 1
#      69                 else:
# ---> 70                     model.sim_step()
#      71                     model.create_output()
#      72                 yield model.t
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\agentpy\model.py in sim_step(self)
#     316         and then calling :func:`Model.step` and :func:`Model.update`."""
#     317         self.t += 1
# --> 318         self.step()
#     319         self.update()
#     320         if self.t >= self._steps:
#
# d:\Code\MultiagentTrafficSys\model\TrafficModel.py in step(self)
#      43
#      44             if nearest_car != None:
# ---> 45                 speed = car.calc_speed(nearest_car.get_position(), mindistance)
#      46
#      47
#
# TypeError: calc_speed() takes 2 positional arguments but 3 were given
